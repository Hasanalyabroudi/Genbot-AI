# %%
MONGO_DB_PASSWORD = "genbot_ai_db"
MONGO_DB_USERNAME = "genbot"
MONGO_CONNECTION_STRING = "mongodb://genbot:genbot_ai_db@52.188.193.108:27017/?directConnection=true&appName=mongosh+2.4.2"

# %%
from dbs.mongo_db.db import db as mongo_db

mongo_db_ = mongo_db(
        MONGO_CONNECTION_STRING,
        f'www_uottawa_ca_db'
    )

# %%
mongo_db_.connect()
# Out:
# Successfully connected to the database: page_content

# %%
table = mongo_db_.get_internal_links(ids=ids)
# Out:
# Processing IDs: 100%|█████████████████████████████████████████████████████████████| 1000/1000 [00:09<00:00, 102.81it/s]
#                                                  url n_internal_links
# 0   http://catalogue.uottawa.ca/search/?P=THE%204920               23
# 0   http://catalogue.uottawa.ca/search/?P=GEG%202320               19
# 0  https://www.uottawa.ca/cdn-cgi/l/email-protect...                0
# 0  https://catalogue.uottawa.ca/search/?P=ILA%202902               21
# 0  https://catalogue.uottawa.ca/search/?P=EVD%205509               20

# %%
table
# Out:
# {'http://catalogue.uottawa.ca/search/?P=THE%204920': 23,
#  'http://catalogue.uottawa.ca/search/?P=GEG%202320': 19,
#  'https://www.uottawa.ca/cdn-cgi/l/email-protection#2e495d404141456e5a4146004d4f': 0,
#  'https://catalogue.uottawa.ca/search/?P=ILA%202902': 21,
#  'https://catalogue.uottawa.ca/search/?P=EVD%205509': 20,
#  'https://uniweb.uottawa.ca/network/profile/members/4250': 0,
#  'http://catalogue.uottawa.ca/search/?P=MCG%202541': 19,
#  'https://www.uottawa.ca/faculte-sciences-sociales/affaires-publiques-internationales/etudes-superieures': 43,
#  'http://catalogue.uottawa.ca/fr/etudes-sup/maitrise-arts-theatre-specialisation-etudes-medievales-renaissance/': 49,
#  'https://catalogue.uottawa.ca/fr/chercher/?search=ANT%202530': 21,
#  'https://www.uottawa.ca/faculte-medecine/dr-richard-waldolf': 1,
#  'https://www.uottawa.ca/faculte-sciences-sociales/toutes-nouvelles/lallemagne-vote-table-ronde-decrypter-tournant-politique-majeur': 6,
# ...

# %%
ids = mongo_db_.find_all_ids()

# %%
ids = ids[:1000]

# %%
import pandas as pd

# %%
urls = pd.DataFrame(columns=['url'])

# %%
urls = []

# %%
i = 0 
for id in ids:
    i=i+1
    urls.append(id['url'])
    if i%1000 == 0:
        print(i)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000

# %%
table['n_internal_links'].value_counts()
# Out:
# n_internal_links
# 0      11996
# 19      3786
# 1       1749
# 20      1699
# 21      1504
#        ...
# 321        1
# 166        1
# 339        1
# 372        1
# 174        1
# Name: count, Length: 252, dtype: int64

# %%
print(urls[100])
# Out:
# http://catalogue.uottawa.ca/search/?P=GEG%202320
